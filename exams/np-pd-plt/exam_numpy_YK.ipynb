# %% [markdown]
# # Vraag 1
# In de volgende Pythoncode bevat de array *temperaturen* de maximumtemperaturen voor de dagen van maandag tot en met zondag voor drie steden:
# |Stad      |Maandag  |Dinsdag  |Woensdag  |Donderdag  |Vrijdag  |Zaterdag  |Zondag |
# |----------|--------:|--------:|---------:|----------:|--------:|---------:|-------:|
# |Antwerpen |     -4  |     6   |      4   |      1    |     1   |     7    |   -4   |
# |Leuven    |      5  |    -2   |     -4   |      2    |     9   |     6    |    6   |
# |Mechelen  |      5  |     6   |      2   |     -4    |     7   |     1    |    2   |
#
# Vul de functie *hoogste_temperatuur* aan zodat het programma de hoogste temperatuur in de array afdrukt.
#
# Verwachte output:
# Hoogste temperatuur= 9°C
#
# Plak jouw code voor de functie *hoogste_temperatuur* in de Syntra-leeromgeving.

# %%
import numpy as np
dagen = np.array(["Maandag", "Dinsdag", "Woensdag", "Donderdag", "Vrijdag", "Zaterdag", "Zondag"])
steden = np.array(["Antwerpen", "Leuven", "Mechelen"])
rng = np.random.default_rng(42)
temperaturen = rng.integers(-5, 10, (steden.size, dagen.size))
print('De temperaturen:', temperaturen, sep='\n')

def hoogste_temperatuur(temp):
    return np.max(temp)

print(f"Hoogste temperatuur= {hoogste_temperatuur(temperaturen)}°C")
# Out:
# De temperaturen:
# [[-4  6  4  1  1  7 -4]
#  [ 5 -2 -4  2  9  6  6]
#  [ 5  6  2 -4  7  1  2]]
# Hoogste temperatuur= 9°C

# %% [markdown]
# # Vraag 2
# We vertrekken van dezelfde code. Zorg ervoor dat de functie *gemiddelde_temperatuur_in_leuven* de gemiddelde temperatuur van de laatste rij teruggeeft.
#
# Verwachte output:
# Gemiddelde temperatuur in Leuven = 2.7°C
#
# Plak jouw code voor de functie *gemiddelde_temperatuur_in_leuven* in de Syntra-leeromgeving.

# %%
import numpy as np
dagen = np.array(["Maandag", "Dinsdag", "Woensdag", "Donderdag", "Vrijdag", "Zaterdag", "Zondag"])
steden = np.array(["Antwerpen", "Leuven", "Mechelen"])
rng = np.random.default_rng(42)
temperaturen = rng.integers(-5, 10, (steden.size, dagen.size))
#print('De temperaturen:', temperaturen, sep='\n')

def gemiddelde_temperatuur_in_leuven(temp):
    return np.mean(temp[-1, :]) # or: temp[-1]

print(f"Gemiddelde temperatuur in Leuven = {gemiddelde_temperatuur_in_leuven(temperaturen):.1f}°C")
# Out:
# Gemiddelde temperatuur in Leuven = 2.7°C

# %% [markdown]
# # Vraag 3
# En nog een vraag bij deze code. Zorg ervoor dat de functie *laagste_temperatuur_op_maandag* de laagste temperatuur in de eerste kolom teruggeeft.
#
# Verwachte output:
# Laagste temperatuur op maandag = -4°C
#
# Plak jouw code voor de functie *laagste_temperatuur_op_maandag* in de Syntra-leeromgeving.

# %%
import numpy as np
dagen = np.array(["Maandag", "Dinsdag", "Woensdag", "Donderdag", "Vrijdag", "Zaterdag", "Zondag"])
steden = np.array(["Antwerpen", "Leuven", "Mechelen"])
rng = np.random.default_rng(42)
temperaturen = rng.integers(-5, 10, (steden.size, dagen.size))
#print('De temperaturen:', temperaturen, sep='\n')

def laagste_temperatuur_op_maandag(temp):
    return np.min(temp[:, 0])

print(f"Laagste temperatuur op maandag = {laagste_temperatuur_op_maandag(temperaturen)}°C")
# Out:
# Laagste temperatuur op maandag = -4°C

# %% [markdown]
# # Vraag 4
# Er is een fout gebeurd met de metingen in Leuven. Alle temperaturen van Leuven moeten met 1 verhoogd worden. De output moet er als volgt uitzien:
#
# Verwachte output:
# ```
# De correcte temperatuurmatrix:
#     [[-4  6  4  1  1  7 -4]
#      [ 6 -1 -3  3 10  7  7]
#      [ 5  6  2 -4  7  1  2]]
# ```
# Plak jouw code voor *corrigeer_leuven* in de Syntra leeromgeving

# %%
import numpy as np
dagen = np.array(["Maandag", "Dinsdag", "Woensdag", "Donderdag", "Vrijdag", "Zaterdag", "Zondag"])
steden = np.array(["Antwerpen", "Leuven", "Mechelen"])
rng = np.random.default_rng(42)
temperaturen = rng.integers(-5, 10, (steden.size, dagen.size))
#print('De temperaturen:', temperaturen, sep='\n')

#Vul de functie aan zodat de temperatuur van de tweede rij met 1 wordt verhoogd.
def corrigeer_leuven(temp):
    temp[1, :] += 1 # or: temp[[1]] += 1
    return temp

temperaturen = corrigeer_leuven(temperaturen)
print('De correcte temperatuurmatrix:', temperaturen, sep='\n')
# Out:
# De correcte temperatuurmatrix:
# [[-4  6  4  1  1  7 -4]
#  [ 6 -1 -3  3 10  7  7]
#  [ 5  6  2 -4  7  1  2]]

# %% [markdown]
# # Vraag 5
# Vul de functie *gemiddelde_temperatuur_per_dag* aan zodat je een array met de gemiddelde temperaturen voor elke dag teruggeeft.
#
# De verwachte output is:
# ```
#    Maandag   Dinsdag  Woensdag Donderdag   Vrijdag  Zaterdag    Zondag
#        2.0       3.3       0.7      -0.3       5.7       4.7       1.3
# ```
#
# Plak jouw oplossing voor de functie *gemiddelde_termperatuur_per_dag* in de Syntra leeromgeving

# %%
import numpy as np
dagen = np.array(["Maandag", "Dinsdag", "Woensdag", "Donderdag", "Vrijdag", "Zaterdag", "Zondag"])
steden = np.array(["Antwerpen", "Leuven", "Mechelen"])
rng = np.random.default_rng(42)
temperaturen = rng.integers(-5, 10, (steden.size, dagen.size))
#print('De temperaturen:', temperaturen, sep='\n')

#Pas de functie aan zodat ze een array met de gemiddelde temperaturen voor elke dag teruggeeft
def gemiddelde_temperatuur_per_dag(temps):
    gemtemp_per_dag = np.mean(temps, axis=0)
    return gemtemp_per_dag

for dag in dagen:
    print(f"{dag:>10s}", end='')
print()
for temp in gemiddelde_temperatuur_per_dag(temperaturen):
    print(f"{temp:10.1f}", end='')
# Out:
#    Maandag   Dinsdag  Woensdag Donderdag   Vrijdag  Zaterdag    Zondag
#        2.0       3.3       0.7      -0.3       5.7       4.7       1.3

# %% [markdown]
# # Vraag 6
# Vul de functie *hoogste_temperatuur_op_weekdag* aan zodat ze voor elke gemeente de hoogste temperatuur op een weekdag teruggeeft.
#
# De verwachte output is:
# Antwerpen: 6°C
# Leuven: 9°C
# Mechelen: 7°C
#
# Plak jouw versie van *hoogste_temperatuur_op_weekdag* in de Syntra leeromgeving.

# %%
import numpy as np
dagen = np.array(["Maandag", "Dinsdag", "Woensdag", "Donderdag", "Vrijdag", "Zaterdag", "Zondag"])
steden = np.array(["Antwerpen", "Leuven", "Mechelen"])
rng = np.random.default_rng(42)
temperaturen = rng.integers(-5, 10, (steden.size, dagen.size))
#print('De temperaturen:', temperaturen, sep='\n')

def hoogste_temperatuur_op_weekdag(temp):
    hoogste_per_stad = np.max(temp[:, :-2], axis=1)
    return hoogste_per_stad

for stad, temp in zip(steden, hoogste_temperatuur_op_weekdag(temperaturen)):
    print(f"{stad}: {temp}°C")
# Out:
# Antwerpen: 6°C
# Leuven: 9°C
# Mechelen: 7°C

# %% [markdown]
# # Vraag 7
# De volgende code download de Titanic dataset van Kaggle. Je vindt de beschrijving van die dataset [hier](https://www.kaggle.com/datasets/yasserh/titanic-dataset).

# %%
from zipfile import ZipFile
import numpy as np
import requests
DATA_ZIP = 'data.zip'
data = requests.get('https://www.kaggle.com/api/v1/datasets/download/yasserh/titanic-dataset')
with open(DATA_ZIP, 'wb') as f:
  f.write(data.content)
with open(DATA_ZIP, 'rb') as f:
  ZipFile(f).extractall()

# %% [markdown]
# Vul de code aan met berekeningen voor *aantal_overleefd_eerste_klasse* en *percentage_overleefd_eerste_klasse* zodat je de volgende output krijgt:
#
# In eerste klasse hebben 136 passagiers de ramp overleefd.
# Dat is 63% van de passagiers in eerste klasse.
#
# Plak je code in de Syntra leeromgeving

# %%
import numpy as np
TITANIC_CSV = 'Titanic-Dataset.csv'
overleefden = np.genfromtxt(TITANIC_CSV, delimiter=",", skip_header=1, usecols=1, converters={1: lambda s: s=='1'})
klassen = np.genfromtxt(TITANIC_CSV, delimiter=",", skip_header=1, usecols=2, dtype=np.int8)

# schrijf de correcte expressies voor de volgende twee variabelen
aantal_overleefd_eerste_klasse = np.count_nonzero((klassen==1) & (overleefden))
percentage_overleefd_eerste_klasse = aantal_overleefd_eerste_klasse/np.count_nonzero(klassen==1)*100
print(f"In eerste klasse hebben {aantal_overleefd_eerste_klasse} passagiers de ramp overleefd.")
print(f"Dat is {percentage_overleefd_eerste_klasse:.0f}% van de passagiers in eerste klasse." )
# Out:
# In eerste klasse hebben 136 passagiers de ramp overleefd.
# Dat is 63% van de passagiers in eerste klasse.

# %% [markdown]
# # Vraag 8
# Volgens de film 'Titanic' van James Cameron waren Rose DeWitt en Jack Dawson aan boord van de Titanic. Vul de code en de functie *test_namen* aan zodat je antwoorden kunt geven op de volgende vragen:
# - was er iemand met de naam Cameron aan boord? (dat was inderdaad het geval, maar zoek het uit met Numpy)
# - was er iemand met de naam Dawson aan boord? (dat zul je zelf moeten uitzoeken)
#
# Verwachte output:
# ```
# Cameron was boord
# Dawson was ...
# ```
# Plak je volledige programma in de Syntra leeromgeving.

# %%
import numpy as np

TITANIC_CSV = 'Titanic-Dataset.csv'

namen = np.genfromtxt(TITANIC_CSV, delimiter=",", dtype=str, skip_header=1, usecols=3, encoding='UTF-8')
namen = np.strings.replace(namen, '"', '')
# print(namen)

# Vul de functie aan zodat ze de juiste output afdrukt.
def test_naam(namenlijst, naam):
    return np.isin(naam, namenlijst) # or: np.any(namenlijst==naam)

for n in ('Cameron', 'Hockley', 'Dawson'):
    ans = "was"
    if not test_naam(namen, n):
        ans += " niet"
    print(f"{n} {ans} boord")
# Out:
# Cameron was boord
# Hockley was not boord
# Dawson was not boord

# %% [markdown]
# # Vraag 9
# We keren terug naar de code van de eerste vraag. Vul de functie *gemiddelde_temperatuur_in* aan zodat de returnwaarde de gemiddelde temperatuur in *stad* teruggeeft. Wanneer er geen data is over die stad, moet de code een exception geven.
#
# Verwachte output:
# De gemiddelde temperatuur in Leuven was 3.1°C
# De gemiddelde temperatuur in Mechelen was 2.7°C
# Voor Brussel hebben we geen temperatuur.
#
# Trek je niets aan van de *with warnings.catch_warnings*-constructie. Sommige mogelijke oplossingen (want er zijn meerdere mogelijkheden) genereren een RuntimeWarning. De *with warnings.catch_warnings*-constructie zorgt ervoor dat die RuntimeWarning niet wordt getoond. (het zou kunnen dat jouw oplossing geen RuntimeWarning genereert. Dus trek je er niets van aan).
# Plak jouw code voor de functie *gemiddelde_temperatuur_in* in de Syntra-leeromgeving.

# %%
import numpy as np
import warnings
dagen = np.array(["Maandag", "Dinsdag", "Woensdag", "Donderdag", "Vrijdag", "Zaterdag", "Zondag"])
steden = np.array(["Antwerpen", "Leuven", "Mechelen"])
rng = np.random.default_rng(42)
temperaturen = rng.integers(-5, 10, (steden.size, dagen.size))
#print('De temperaturen:', temperaturen, sep='\n')

#Pas de volgende functie aan
def gemiddelde_temperatuur_in(arr_temps, arr_steden, locatie):
    if np.isin(locatie, arr_steden):  # or: if np.count_nonzero(is_stad) == 0 (is_stad = arr_steden == locatie)
        temps = arr_temps[arr_steden == locatie]
        return np.mean(temps)
    else:
        raise IndexError

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    for stad in ('Leuven', 'Mechelen', 'Brussel'):
        try:
            gemiddelde_temperatuur = gemiddelde_temperatuur_in(temperaturen, steden, stad)
            print(f'De gemiddelde temperatuur in {stad} was {gemiddelde_temperatuur:.1f}°C')
        except IndexError:
            print(f'Voor {stad} hebben we geen temperatuur.')
# Out:
# De gemiddelde temperatuur in Leuven was 3.1°C
# De gemiddelde temperatuur in Mechelen was 2.7°C
# Voor Brussel hebben we geen temperatuur.

# %% [markdown]
# # Vraag 10
# Je weet ondertussen dat er een passagier met de naam Cameron aan boord was. Schrijf Numpy code waarmee je toont wat de volledige naam was van die passagier en hoeveel zij moest betalen (*fare*).
#
# Verwachte output:
# Passagier "Cameron, Miss. Clear Annie" betaalde £21.0.
#
# Plak je volledige programma in de Syntra leeromgeving.

# %%
import csv

# omvormen de csv naar punt-komma delimiter
TITANIC_CSV = 'Titanic-Dataset.csv'
TITANIC_PCSV = 'Titanic.csv'
with open(TITANIC_CSV, 'r') as bestand:
    reader = csv.DictReader(bestand, delimiter=',', quotechar='"')
    with open(TITANIC_PCSV, 'w', newline='') as bestand2:
        writer = csv.DictWriter(bestand2, fieldnames=reader.fieldnames, delimiter=';')
        writer.writeheader()
        writer.writerows(reader)

namen = np.genfromtxt(TITANIC_PCSV, delimiter=";", dtype=str, skip_header=1, usecols=3, encoding='UTF-8')
fares = np.genfromtxt(TITANIC_PCSV, delimiter=";", dtype=np.float64, skip_header=1, usecols=-3)
#print(namen, fares)
naam = np.strings.startswith(namen, "Cameron")
print(f"Passagier {namen[naam][0]} betaalde £{fares[naam][0]}.")
# Out:
# Passagier Cameron, Miss. Clear Annie betaalde £21.0.

# %% [markdown]
# # Vraag 11
# De onderstaande code maakt een bestand met de (verwachte) verkoopcijfers voor elke dag van de maand februari 2026. Ter info: 1 februari 2026 valt op een zondag. Maar op zondag is de winkel gesloten, dus vandaar dat het verkoopcijfer voor elke zondag 0 is.
#
# Gevraagd: lees dit bestand met NumPy en genereer een lijst met de som van de verkopen voor elke week. Zorg dat je de volgende output genereert:
# ```
# Op zaterdag 2026-02-07 is er gedurende de hele week voor €12487 verkocht.
# Op zaterdag 2026-02-14 is er gedurende de hele week voor €12586 verkocht.
# Op zaterdag 2026-02-21 is er gedurende de hele week voor €12433 verkocht.
# Op zaterdag 2026-02-28 is er gedurende de hele week voor €13517 verkocht.
# ```
# Plak je code in de Syntra leeromgeving.

# %%
from datetime import date, timedelta
verkopen = [0, 2547, 2309, 1877, 1866, 2717, 1171, 0, 1402, 1188, 2052,
       2951, 2471, 2522, 0, 2572, 2026, 1256, 2679, 1900, 2000, 0,
       1365, 2853, 2563, 2287, 1804, 2645]
dagen = [date(2026, 2, 1) + timedelta(dag) for dag in range(28)]
MAANDOMZET_CSV = 'maandomzet.csv'
with open(MAANDOMZET_CSV, mode='w') as f:
    print('dag;verkoopcijfer', file=f)
    for dag, cijfer in zip(dagen, verkopen):
        print(f"{dag};{cijfer}", file=f)
# Out:
# [datetime.date(2026, 2, 1), datetime.date(2026, 2, 2), datetime.date(2026, 2, 3), datetime.date(2026, 2, 4), datetime.date(2026, 2, 5), datetime.date(2026, 2, 6), datetime.date(2026, 2, 7), datetime.date(2026, 2, 8), datetime.date(2026, 2, 9), datetime.date(2026, 2, 10), datetime.date(2026, 2, 11), datetime.date(2026, 2, 12), datetime.date(2026, 2, 13), datetime.date(2026, 2, 14), datetime.date(2026, 2, 15), datetime.date(2026, 2, 16), datetime.date(2026, 2, 17), datetime.date(2026, 2, 18), datetime.date(2026, 2, 19), datetime.date(2026, 2, 20), datetime.date(2026, 2, 21), datetime.date(2026, 2, 22), datetime.date(2026, 2, 23), datetime.date(2026, 2, 24), datetime.date(2026, 2, 25), datetime.date(2026, 2, 26), datetime.date(2026, 2, 27), datetime.date(2026, 2, 28)] [0, 2547, 2309, 1877, 1866, 2717, 1171, 0, 1402, 1188, 2052, 2951, 2471, 2522, 0, 2572, 2026, 1256, 2679, 1900, 2000, 0, 1365, 2853, 2563, 2287, 1804, 2645]
