# %% [markdown]
# # Random Forest - Classificatie

# %% [markdown]
# ## Data
#
# We werken opnieuw met de pinguin dataset.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/penguins_size.csv")

# %%
df = df.dropna()  # droppen van de ontbrekende datapunten
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %% [markdown]
# ## Train | Test Split

# %%
X = pd.get_dummies(df.drop('species',axis=1),drop_first=True)
y = df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# help(RandomForestClassifier)

# %%
# Use 10 random trees
model = RandomForestClassifier(n_estimators=10,
                               max_features='sqrt',
                               random_state=101)  # de willekeurige selectie van subsets van features 
                                                  # bij elke splitsing v/e tree wordt reproduceerbaar.  
# Met andere woorden, als je de random forest met dezelfde random_state en dezelfde data opnieuw traint, 
# zal het dezelfde willekeurige subsets van features selecteren voor elke boom als in de vorige training.

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=101)

# %%
preds = model.predict(X_test)

# %%
preds
# Out:
# array(['Chinstrap', 'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Adelie', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo',
#        'Adelie', 'Adelie', 'Adelie', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Adelie', 'Adelie',
#        'Gentoo', 'Gentoo', 'Chinstrap', 'Adelie', 'Chinstrap',
#        'Chinstrap', 'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Adelie', 'Gentoo', 'Chinstrap', 'Chinstrap', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo', 'Adelie',
# ...

# %% [markdown]
# ## Evaluatie

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %%
confusion_matrix(y_test,preds)
# Out:
# array([[39,  2,  0],
#        [ 1, 22,  0],
#        [ 0,  0, 37]])

# %%
# Idem: confusion matrix, maar mooi geplot - Ruwe waarden
cm = confusion_matrix(y_test, preds, labels=model.classes_)

disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot();

# %%
# 3 foutief geclassificeerde pinguins!

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %% [markdown]
# ## Feature Importance
#
# We kunnen opvragen hoe belangrijk elke feature is in het voorspellen van de klasse!

# %%
model.feature_importances_
# Out:
# array([0.31867744, 0.1018487 , 0.17343398, 0.21316964, 0.14512091,
#        0.03720114, 0.00632264, 0.00422556])

# %% [markdown]
# 8 features door dummy encoding!

# %%
# how to get features names?
for score, name in zip(model.feature_importances_, X_train.columns):
    print(round(score, 2), name)
# Out:
# 0.32 culmen_length_mm
# 0.1 culmen_depth_mm
# 0.17 flipper_length_mm
# 0.21 body_mass_g
# 0.15 island_Dream
# 0.04 island_Torgersen
# 0.01 sex_FEMALE
# 0.0 sex_MALE

# %% [markdown]
# ## Keuze van het aantal trees

# %% [markdown]
# We controleren of het laten toenemen van het aantal trees de performantie van het model ten goede komt...

# %%
test_error = []

for n in range(1,40):
    # Gebruik n random trees
    model = RandomForestClassifier(n_estimators=n,max_features='sqrt')
    model.fit(X_train,y_train)
    test_preds = model.predict(X_test)
    test_error.append(1-accuracy_score(test_preds,y_test))

# %%
plt.plot(range(1,40),test_error,label='Test Error')
plt.legend()
plt.show()

# %% [markdown]
# We zien duidelijk dat de meerwaarde van bijkomende trees op een dergelijke kleine dataset beperkt is.  Vanaf een 5-tal trees kunnen we stellen dat alle in de dataset beschikbare informatie wordt gebruikt.

# %% [markdown]
# # Random Forest - HyperParameters
#
# We gaan nu een grotere dataset gebruiken om een meer realistische workflow te zien voor Random Forests. Dit houdt ook een GridSearch in met Cross-Validation.  We gebruiken hiervoor de banknote authentication data set van UC Irvine ML Data Repository.

# %% [markdown]
# Gegevens werden geëxtraheerd uit echte en vervalste bankbiljetten. Voor de digitalisatie werd een industriële camera gebruikt die normaal wordt ingezet voor drukinspectie. De uiteindelijke afbeeldingen hebben 400 x 400 pixels. Er werden grijsschaalafbeeldingen verkregen met een resolutie van ongeveer 660 dpi. Een Wavelet Transformatie werd gebruikt om kenmerken uit de afbeeldingen te extraheren.  Een wavelet transformatie kan worden gebruikt om kenmerken of patronen in de afbeeldingen te identificeren die niet gemakkelijk waarneembaar zijn in de ruwe pixelgegevens. Dit kan onder andere nuttig zijn voor taken zoals patroonherkenning, beeldcompressie en de detectie van vervalsingen.  Een wavelet transformatie gebruikt golffuncties, genaamd wavelets, om complexe signalen te analyseren.
#
# **De dataset features zijn:**
#
# -Variantie van de wavelet transformatie
# -Scheefheid van de wavelet transformatie
# -Kurtosis van de wavelet transformatie (Kurtosis is een statistische maat die de "spitsheid" of "afgeplatheid" van de verdeling van een reeks gegevens beschrijft in vergelijking met een normale verdeling)
# -Entropie van de afbeelding (De entropie van een afbeelding is een maat voor de hoeveelheid informatie die door de pixelwaarden van de afbeelding wordt overgebracht. Een hoge entropie in een afbeelding betekent dat er veel variatie is in de pixelwaarden, wat wijst op een complex beeld met veel details. Een afbeelding met een lage entropie bevat daarentegen weinig variatie in pixelwaarden en is dus relatief eenvoudig of eentonig.)

# %%
df = pd.read_csv("../data/data_banknote_authentication.csv")

# %%
df.head()
# Out:
#    Variance_Wavelet  Skewness_Wavelet  Curtosis_Wavelet  Image_Entropy  Class
# 0           3.62160            8.6661           -2.8073       -0.44699      0
# 1           4.54590            8.1674           -2.4586       -1.46210      0
# 2           3.86600           -2.6383            1.9242        0.10645      0
# 3           3.45660            9.5228           -4.0112       -3.59440      0
# 4           0.32924           -4.4552            4.5718       -0.98880      0

# %%
# pairplot van de volledige dataset
sns.pairplot(df,hue='Class')

# %% [markdown]
# Er is een duidelijk onderscheid in de distributie van de echte en de vervalste bankbiljetten. Voor sommige feature combinaties is er weinig onderscheid, maar bij andere combinaties is er een duidelijk verschil.  We verwachten dus een goed model.

# %% [markdown]
# **Schalen van de data**
#
# Aangezien we telkens één feature behandelen om een split op te doen, hoeven we data niet te schalen.

# %%
X = df.drop("Class", axis=1)

# %%
y = df["Class"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=101)

# %%
from sklearn.model_selection import GridSearchCV

# %%
n_estimators=[64, 100, 128, 200]
max_features= [2, 3, 4]  # er zijn slechts 4 features
bootstrap = [True, False]
oob_score = [True, False]

# %%
param_grid = {'n_estimators': n_estimators,
             'max_features': max_features,
             'bootstrap': bootstrap,
             'oob_score': oob_score}  # oob_score is enkel zinvol indien bootstrap=True anders zal de fit failen

# %%
rfc = RandomForestClassifier()
# opzetten GridSearch
grid = GridSearchCV(rfc, param_grid)

# %%
grid.fit(X_train, y_train)
# Out:
# c:\Users\Cursist\DataScienceCourse\DS_Projects\venv_ml\Lib\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 60 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Cursist\DataScienceCourse\DS_Projects\venv_ml\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Cursist\DataScienceCourse\DS_Projects\venv_ml\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
# ...

# %%
grid.best_params_
# Out:
# {'bootstrap': True, 'max_features': 2, 'n_estimators': 64, 'oob_score': True}

# %% [markdown]
# oob_score: False: dit is puur toevallig; het wijzigt de training niet.  Indien je dit model met oob_score True wenst, moet je dit zelf maken!

# %%
# aanmaken beste model met oob_score:
rfc = RandomForestClassifier(max_features=2, n_estimators=200, oob_score=True)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=2, n_estimators=200, oob_score=True)

# %%
rfc.oob_score_
# Out:
# 0.9939965694682675

# %%
predictions = grid.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       124
#            1       0.98      1.00      0.99        82
#
#     accuracy                           0.99       206
#    macro avg       0.99      0.99      0.99       206
# weighted avg       0.99      0.99      0.99       206

# %%
# confusion matrix
cm = confusion_matrix(y_test, predictions, labels=grid.classes_)

disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=grid.classes_)
disp.plot()

# %% [markdown]
# We hebben maar één biljet foutief geclassificeerd!

# %%
# Geen underscore, geeft de originele oob_score parameter weer
grid.best_estimator_.oob_score
# Out:
# True

# %%
# Met underscore, krijg je de waarde terug - die moeten we van het apart gefitte model krijgen!
rfc.oob_score_
# Out:
# 0.9939965694682675

# %% [markdown]
# ## Het aantal Estimators (Trees)
#
# We bekijken nu error vs. Aantal Estimators

# %%
from sklearn.metrics import accuracy_score

# %%
errors = []
misclassifications = []

for n in range(1, 200):
    rfc = RandomForestClassifier( n_estimators=n,bootstrap=True,max_features= 2)  # 2 = sqrt(4)
    rfc.fit(X_train,y_train)
    preds = rfc.predict(X_test)
    err = 1 - accuracy_score(preds,y_test)
    n_missed = np.sum(preds != y_test)
    errors.append(err)
    misclassifications.append(n_missed)

# %%
plt.plot(range(1, 200), errors);

# %%
plt.plot(range(1, 200), misclassifications);
